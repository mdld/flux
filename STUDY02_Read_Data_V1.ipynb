# %% [markdown]
# <a href="https://colab.research.google.com/github/mdld/flux/blob/main/STUDY02_Read_Data_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
try:
  from google.colab import drive
  drive.mount('/gdrive')
  # %cd /gdrive/.shortcut-targets-by-id/1Ceqqrb_wsA6SDV82I0HBzLQ17ezMt9v2/MariePHD
except ImportError:
  print("Can't import colab drive, hopefully this means you're running locally")
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/.shortcut-targets-by-id/1Ceqqrb_wsA6SDV82I0HBzLQ17ezMt9v2/MariePHD

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
header_list = ["A0L", "A0V", "A1L", "A1V", "A2L", "A2V", "A3L", "A3V", "A4L", "A4V", "A5L", "A5V", "A6L", "A6V"]

# %%
select_participant = 4

# %%
if (select_participant == 1):
  df1 = pd.read_csv("STUDY02/Participant1/Data_230_56.csv",sep=",",names=header_list,skiprows=3)
  df2 = pd.read_csv("STUDY02/Participant1/Data_230_57.csv",sep=",",names=header_list,skiprows=3)
  df3 = pd.read_csv("STUDY02/Participant1/Data_230_58.csv",sep=",",names=header_list,skiprows=3)
  df4 = pd.read_csv("STUDY02/Participant1/Data_230_59.csv",sep=",",names=header_list,skiprows=3)
  df5 = pd.read_csv("STUDY02/Participant1/Data_230_60.csv",sep=",",names=header_list,skiprows=3)
  df6 = pd.read_csv("STUDY02/Participant1/Data_230_61.csv",sep=",",names=header_list,skiprows=3)

# %%
if (select_participant == 2):
  df1 = pd.read_csv("STUDY02/Participant2/Data_266_65.csv",sep=",",names=header_list,skiprows=3)
  df2 = pd.read_csv("STUDY02/Participant2/Data_266_66.csv",sep=",",names=header_list,skiprows=3)
  df3 = pd.read_csv("STUDY02/Participant2/Data_266_67.csv",sep=",",names=header_list,skiprows=3)
  df4 = pd.read_csv("STUDY02/Participant2/Data_266_68.csv",sep=",",names=header_list,skiprows=3)
  df5 = pd.read_csv("STUDY02/Participant2/Data_266_69.csv",sep=",",names=header_list,skiprows=3)
  df6 = pd.read_csv("STUDY02/Participant2/Data_266_70.csv",sep=",",names=header_list,skiprows=3)

# %%
if (select_participant == 3):
  df1 = pd.read_csv("STUDY02/Participant3/Data_267_71.csv",sep=",",names=header_list,skiprows=3)
  df2 = pd.read_csv("STUDY02/Participant3/Data_267_72.csv",sep=",",names=header_list,skiprows=3)
  df3 = pd.read_csv("STUDY02/Participant3/Data_267_73.csv",sep=",",names=header_list,skiprows=3)
  df4 = pd.read_csv("STUDY02/Participant3/Data_267_74.csv",sep=",",names=header_list,skiprows=3)
  df5 = pd.read_csv("STUDY02/Participant3/Data_267_75.csv",sep=",",names=header_list,skiprows=3)
  df6 = pd.read_csv("STUDY02/Participant3/Data_267_76.csv",sep=",",names=header_list,skiprows=3)

# %%
if (select_participant == 4):
  df1 = pd.read_csv("STUDY02/Participant4/Data_267_77.csv",sep=",",names=header_list,skiprows=3)
  df2 = pd.read_csv("STUDY02/Participant4/Data_267_78.csv",sep=",",names=header_list,skiprows=3)
  df3 = pd.read_csv("STUDY02/Participant4/Data_267_79.csv",sep=",",names=header_list,skiprows=3)
  df4 = pd.read_csv("STUDY02/Participant4/Data_267_80.csv",sep=",",names=header_list,skiprows=3)
  df5 = pd.read_csv("STUDY02/Participant4/Data_267_81.csv",sep=",",names=header_list,skiprows=3)
  df6 = pd.read_csv("STUDY02/Participant4/Data_267_82.csv",sep=",",names=header_list,skiprows=3)

# %%
df1.drop(["A0L","A0V","A1L","A2L","A3L","A4L","A5L","A6L"], axis=1, inplace=True)
df2.drop(["A0L","A0V","A1L","A2L","A3L","A4L","A5L","A6L"], axis=1, inplace=True)
df3.drop(["A0L","A0V","A1L","A2L","A3L","A4L","A5L","A6L"], axis=1, inplace=True)
df4.drop(["A0L","A0V","A1L","A2L","A3L","A4L","A5L","A6L"], axis=1, inplace=True)
df5.drop(["A0L","A0V","A1L","A2L","A3L","A4L","A5L","A6L"], axis=1, inplace=True)
df6.drop(["A0L","A0V","A1L","A2L","A3L","A4L","A5L","A6L"], axis=1, inplace=True)

# %%
df1.insert(0, 'New_ID', range(1, 1 + len(df1)))
df2.insert(0, 'New_ID', range(1, 1 + len(df2)))
df3.insert(0, 'New_ID', range(1, 1 + len(df3)))
df4.insert(0, 'New_ID', range(1, 1 + len(df4)))
df5.insert(0, 'New_ID', range(1, 1 + len(df5)))
df6.insert(0, 'New_ID', range(1, 1 + len(df6)))

# %% [markdown]
# Video 1: Surprise

# %%
lines = df1.plot.line(x="New_ID",ylim=(100,300),figsize=(25,10))

# %% [markdown]
# Video 2: Sadness

# %%
lines = df2.plot.line(x="New_ID",ylim=(100,300),figsize=(25,10))

# %% [markdown]
# Video 3: Joy

# %%
lines = df3.plot.line(x="New_ID",ylim=(100,300),figsize=(25,10))

# %% [markdown]
# Video 4: Fear

# %%
lines = df5.plot.line(x="New_ID",ylim=(100,300),figsize=(25,10))

# %% [markdown]
# Video 5: Anger

# %%
lines = df5.plot.line(x="New_ID",ylim=(100,300),figsize=(25,10))

# %% [markdown]
# Video 6: Disgust

# %%
lines = df6.plot.line(x="New_ID",ylim=(100,300),figsize=(25,10))
